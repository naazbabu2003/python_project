# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

file_path = 'C:\\Users\\OP NAAZ\\OneDrive\\Desktop\\orders.xlsx'

try:
    with open(file_path, 'r') as file:
        # Process the file
        pass
except FileNotFoundError:
    print("The file was not found.")
except PermissionError:
    print("Permission denied. Please check your file permissions.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
file_path
# Out:
# 'C:\\Users\\OP NAAZ\\OneDrive\\Desktop\\orders.xlsx'

# %%
file_path = r'C:\Users\OP NAAZ\OneDrive\Desktop\orders.xlsx'

try:
    df = pd.read_excel(file_path, engine='openpyxl')
    print(df)
except FileNotFoundError:
    print("The file was not found.")
except PermissionError:
    print("Permission denied. Please check your file permissions.")
except UnicodeDecodeError as e:
    print(f"Unicode decode error: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
pd.isnull(df).sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.describe(
)
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355648
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.989494
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# ...

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
a=sbn.barplot(x='Category',y='Sales',data=df)

# %% [markdown]
# # sales by category sabse jyda salse technology ka hua hai then uske bad furniture then uske bad others.

# %%
a=sbn.barplot(y='Profit',x='Category',data=df)

# %% [markdown]
# # category by profit. jaisa ki furniture ka sales to jyda hai par usak profit minus mai hai magar sabse jyada technolgy profit de rahi hai

# %%
df[df['Category']=='Furniture']['Sales'].sum()
# Out:
# 741999.7953

# %%
df[df['Category'] == 'Furniture']['Profit'].sum()
# Out:
# 18451.272799999984

# %%
df.Category
# Out:
# 0             Furniture
# 1             Furniture
# 2       Office Supplies
# 3             Furniture
# 4       Office Supplies
#              ...
# 9989          Furniture
# 9990          Furniture
# 9991         Technology
# 9992    Office Supplies
# 9993    Office Supplies
# Name: Category, Length: 9994, dtype: object

# %%
a=sbn.countplot(x='Ship Mode',data=df)
for bars in a.containers:
    a.bar_label(bars)

# %% [markdown]
# # Ship Mode. Sabse Jyada customers ne Standard class ship mode kya hai

# %%
a=sbn.barplot(y='Sales',x='Segment',data=df)
for bars in a.containers:
    a.bar_label(bars)
    plt.show()

# %% [markdown]
# # Sales by Segment. Sabse jyada sales segment mai home office ki hui hai

# %%
sales_Region=df.groupby(['Region'],as_index=False)['Sales'].sum().sort_values(by='Sales',ascending=False)
a=sbn.barplot(data=sales_Region,x='Region',y='Sales')
for bars in a.containers:
    a.bar_label(bars)

# %% [markdown]
# # Sum Of Sales by Region. Sabse jyada sales south or east se ho rahi hai

# %%
profit_Region=df.groupby(['Region'],as_index=False)['Profit'].sum().sort_values(by='Profit', ascending=False).head(5)

a=sbn.barplot(data=profit_Region,x='Profit',y='Region')
for container  in a.containers:
    a.bar_label(container)

# %% [markdown]
# # sum of profit by Region > jyada profit west or east se ho rha hai

# %%
df.Profit.sum()
# Out:
# 286397.0216999999

# %%
df.Sales.sum()
# Out:
# 2297200.8603000003

# %%
region_sales = df.groupby('Region')['Sales'].sum().reset_index()

# %%
profit_Region
# Out:
#     Region       Profit
# 3     West  108418.4489
# 1     East   91522.7800
# 2    South   46749.4303
# 0  Central   39706.3625

# %%
region_sales
# Out:
#     Region        Sales
# 0  Central  501239.8908
# 1     East  678781.2400
# 2    South  391721.9050
# 3     West  725457.8245

# %%
region_salessales_state=df.groupby(['State'],as_index=False)['Sales'].sum().sort_values(by='Sales', ascending=False).head(5)



sbn.set(rc={'figure.figsize':(15,5)})
a=sbn.barplot(data=sales_state,x='State',y='Sales')
for container  in a.containers:
    a.bar_label(container)

# %% [markdown]
# # sum of sales by states > sabse jyada sales california se ho raha hai

# %%
profit_state=df.groupby(['State'],as_index=False)['Profit'].sum().sort_values(by='Profit',ascending=False).head(5)
sbn.set(rc={'figure.figsize':(10,5)})
a=sbn.barplot(profit_staet,x='State',y='Profit')
for container  in a.containers:
    a.bar_label(container)

# %% [markdown]
# # sum of profit by states > jyada profit california or New York se hi ho rha hai

# %%
sales_state.reset_index()
# Out:
#    index         State        Sales
# 0      3    California  457687.6315
# 1     30      New York  310876.2710
# 2     41         Texas  170188.0458
# 3     45    Washington  138641.2700
# 4     36  Pennsylvania  116511.9140

# %%
profit_state.reset_index()
# Out:
#    index       State      Profit
# 0      3  California  76381.3871
# 1     30    New York  74038.5486
# 2     45  Washington  33402.6517
# 3     20    Michigan  24463.1876
# 4     44    Virginia  18597.9504

# %%
avg_profit=df.groupby(['State'],as_index=False)['Profit'].mean().sort_values(by='Profit',ascending=False).head(5)
a=sbn.barplot(data=avg_profit,y='State',x='Profit')
for container  in a.containers:
    a.bar_label(container)

# %% [markdown]
# #  Avrage Profit by State, average profit vermont state se ho rha hai hai or rehode

# %%
avg_profit
# Out:
#            State      Profit
# 43       Vermont  204.088936
# 37  Rhode Island  130.100523
# 12       Indiana  123.375411
# 24       Montana  122.221900
# 21     Minnesota  121.608847

# %% [markdown]
# # Analysis
#
#
#
#
# # 1.Sales by Category:
#
# The highest sales are in the Technology category, followed by Furniture, and then Others.
#
# # 2.Category by Profit:
#
# Although Furniture has higher sales, its profit is negative. Technology provides the highest profit.
#
# # 3.Ship Mode:
#
# The majority of customers have chosen Standard Class as their shipping mode.
#
# # 4.Sales by Segment:
#
# The highest sales are in the Home Office segment.
#
# # 5.Sum of Sales by Region:
#
# The highest sales are from the South and East regions.
#
# # 6. Sum of Profit by Region:
#
# The highest profit comes from the West and East regions.
#
# # 7.Sum of Sales by State:
#
# The highest sales are from California.
#
# # 8.Sum of Profit by State:
#
# The highest profit is from California and New York.
#
# # 9.Average Profit by State:
#
# The highest average profit is from Vermont, followed by Rhode Island.
